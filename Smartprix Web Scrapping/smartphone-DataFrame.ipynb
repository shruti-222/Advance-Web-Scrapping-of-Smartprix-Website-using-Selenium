# %%
with open('smartphone.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in g:\data science\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in g:\data science\lib\site-packages (from beautifulsoup4) (2.3.1)

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
soup= BeautifulSoup(html,'lxml')

# %%
container=soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
name = []
price= []
specs =[]

for i in container:
    name.append(i.find('h2').text)
    price.append(i.find('span',{'class':'price'}).text)
    try:
         specs.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
         specs.append(np.nan)

# %%
len(name)
# Out:
# 1020

# %%
df = pd.DataFrame({
    'Model':name,
    'Price':price,
    'Rating:':specs
})

# %%
df
# Out:
#                             Model      Price Rating:
# 0                    Oppo Reno 8T    ₹29,999      86
# 1                   OnePlus 11 5G    ₹56,999      89
# 2       OnePlus Nord CE 2 Lite 5G    ₹18,999      81
# 3                     OnePlus 11R    ₹39,999      85
# 4     Samsung Galaxy S23 Ultra 5G  ₹1,24,999     NaN
# ...                           ...        ...     ...
# 1015                 Karbonn K531     ₹1,299     NaN
# 1016                       TMB T3     ₹1,349     NaN
# 1017                Peace Mi3 Pro       ₹799     NaN
# 1018                Cellecor A40i     ₹1,449     NaN
# 1019                Micromax X413       ₹832     NaN
#
# [1020 rows x 3 columns]

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(name)
# Out:
# 1020

# %%
len(price)
# Out:
# 1020

# %%
len(specs)
# Out:
# 1020

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                             model      price rating  \
# 0                    Oppo Reno 8T    ₹29,999     86
# 1                   OnePlus 11 5G    ₹56,999     89
# 2       OnePlus Nord CE 2 Lite 5G    ₹18,999     81
# 3                     OnePlus 11R    ₹39,999     85
# 4     Samsung Galaxy S23 Ultra 5G  ₹1,24,999    NaN
# ...                           ...        ...    ...
# 1015                 Karbonn K531     ₹1,299    NaN
# 1016                       TMB T3     ₹1,349    NaN
# 1017                Peace Mi3 Pro       ₹799    NaN
# 1018                Cellecor A40i     ₹1,449    NaN
# 1019                Micromax X413       ₹832    NaN
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 4         Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# ...                                                 ...
# 1015                                           Dual Sim
# 1016                                           Dual Sim
# 1017                                           Dual Sim
# 1018                                           Dual Sim
# 1019                                           Dual Sim
#
#                                               processor  \
# 0          Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1       Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 2          Snapdragon 695, Octa Core, 2.2 GHz Processor
# 3      Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 4     Snapdragon 8 Gen 2, Octa Core, 3.36 GHz Processor
# ...                                                 ...
# 1015                                            No Wifi
# 1016                           32 MB RAM, 64 MB inbuilt
# 1017                          64 MB RAM, 128 MB inbuilt
# 1018                                  1.5 MHz Processor
# 1019                                    1 MHz Processor
#
#                             ram                                   battery  \
# 0      8 GB RAM, 128 GB inbuilt   4800 mAh Battery with 67W Fast Charging
# 1      8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 100W Fast Charging
# 2      6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 3      8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 100W Fast Charging
# 4     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 45W Fast Charging
# ...                         ...                                       ...
# 1015            1 MHz Processor                  32 MB RAM, 32 MB inbuilt
# 1016           1050 mAh Battery          1.8 inches, 240 x 320 px Display
# 1017           2500 mAh Battery            2 inches, 320 x 240 px Display
# 1018   32 MB RAM, 32 MB inbuilt                          2000 mAh Battery
# 1019   32 MB RAM, 32 MB inbuilt                           800 mAh Battery
#
#                                                 display  \
# 0     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 2     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 3     6.74 inches, 1240 x 2772 px, 120 Hz Display wi...
# 4     6.8 inches, 1440 x 3088 px, 120 Hz Display wit...
# ...                                                 ...
# 1015                                   1750 mAh Battery
# 1016                                 1.3 MP Rear Camera
# 1017                                 0.3 MP Rear Camera
# 1018                   2.4 inches, 240 x 320 px Display
# 1019                  1.77 inches, 240 x 320 px Display
#
#                                                  camera  \
# 0     108 MP + 2 MP + 2 MP Triple Rear & 32 MP Front...
# 1     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 2     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4                 200 MP Quad Rear & 12 MP Front Camera
# ...                                                 ...
# 1015                   2.4 inches, 240 x 320 px Display
# 1016                                          Bluetooth
# 1017                                                NaN
# 1018                                 0.8 MP Rear Camera
# 1019                                 0.3 MP Rear Camera
#
#                                    card                                 os
# 0      Memory Card Supported, upto 1 TB                        Android v13
# 1             Memory Card Not Supported                        Android v13
# 2       Memory Card (Hybrid), upto 1 TB                        Android v12
# 3                           Android v13                        No FM Radio
# 4             Memory Card Not Supported                        Android v13
# ...                                 ...                                ...
# 1015                 0.3 MP Rear Camera  Memory Card Supported, upto 16 GB
# 1016                                NaN                                NaN
# 1017                                NaN                                NaN
# 1018  Memory Card Supported, upto 32 GB                        No FM Radio
# 1019                        No FM Radio                                NaN
#
# [1020 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     714 non-null    object
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1009 non-null   object
#  9   card       972 non-null    object
#  10  os         905 non-null    object
# dtypes: object(11)
# memory usage: 87.8+ KB
